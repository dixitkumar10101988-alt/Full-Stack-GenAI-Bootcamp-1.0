#        -1.04490139e-01, -5.17874099e-02, -4.24854308e-02,  3.88856977e-02,
#        -2.90507246e-02,  3.69671583e-02,  3.51897217e-02,  7.46557862e-02,
#        -4.22005579e-02,  1.30002759e-02,  1.27585744e-02,  7.70954192e-02,
#         2.72279158e-02,  9.96644124e-02, -5.02893999e-02, -4.13037390e-02,
#        -7.19954297e-02, -7.97835067e-02, -2.48787372e-04, -2.11185198e-02,
#        -5.14029264e-02, -5.18544354e-02, -1.53546501e-02,  8.27283040e-02,
#        -6.48792014e-02, -1.94287132e-02,  8.50966722e-02, -9.21462197e-03,
#        -4.69519272e-02, -1.63229052e-02,  5.42724840e-02, -1.38607423e-03,
#        -2.39973818e-03,  3.34299840e-02, -5.10443859e-02, -1.22926780e-08,
#         2.32550856e-02, -2.09806375e-02,  7.59120435e-02,  1.63630501e-03,
#         7.08805174e-02, -6.38341624e-03,  6.41138153e-03,  1.67991407e-02,
#         2.01205374e-03,  6.90331832e-02,  5.14227115e-02, -1.46538848e-02,
#         7.30924308e-02,  7.36334026e-02,  2.80660018e-02, -1.08501140e-03,
#        -2.30724011e-02,  7.49830231e-02, -3.63362096e-02,  1.71624701e-02,
#         4.99206893e-02, -4.83323596e-02,  8.88131633e-02, -1.04924254e-02,
#         1.56322215e-02, -5.19080833e-02, -4.27304991e-02,  7.23310634e-02,
#        -2.98822615e-02,  6.97089806e-02, -4.64855917e-02,  6.55340478e-02,
#        -4.42334404e-03,  5.01191542e-02, -9.91293974e-03, -7.92729780e-02,
#        -2.65440196e-02,  4.97001642e-03,  2.09285412e-03, -3.94218788e-03,
#         9.17477254e-03,  2.35563144e-02, -6.17845431e-02,  7.18515180e-03,
#         1.06594013e-02, -8.72101542e-03, -4.47176471e-02, -1.28333420e-01,
#        -4.42111380e-02, -1.66900214e-02,  1.84060913e-02, -6.92470872e-04,
#         1.18215434e-01,  7.96367228e-02,  5.86653240e-02, -1.67979393e-03,
#        -6.23596413e-03,  9.98795591e-03, -6.36940151e-02,  6.97145388e-02,
#         1.49552122e-01,  3.51513103e-02,  4.92654592e-02, -8.68301764e-02],
#       dtype=float32)

# %%
len(embedding)
# Out:
# 384

# %%
embedding.shape
# Out:
# (384,)

# %%
sentence = "How to reduce heart disease risk?"

# %%
embedding =open_source_embedding_model.encode(sentence)

# %%
embedding.shape
# Out:
# (384,)

# %%
paragraph = """
Machine learning is a field of artificial intelligence that focuses on building systems 
that learn from data. It is widely used in applications like recommendation systems, 
image recognition, and natural language processing.
"""

# %%
embedding = open_source_embedding_model.encode(paragraph)

# %%
embedding.shape
# Out:
# (384,)

# %%
embedding
# Out:
# array([-2.78187152e-02, -6.40670443e-03,  3.68498228e-02,  2.21401197e-03,
#         2.55084168e-02,  1.34022525e-02,  6.45559002e-03, -3.05501148e-02,
#        -6.01915568e-02, -2.28517931e-02, -7.05489889e-02,  1.97643079e-02,
#         5.54116443e-02, -3.38736661e-02, -9.74509865e-03,  4.72750701e-02,
#        -1.58115756e-02, -1.64723899e-02, -6.00374974e-02, -7.00235516e-02,
#         2.54246481e-02, -5.45077445e-03, -7.51983300e-02,  1.57804471e-02,
#        -1.35849565e-02, -2.43556593e-02,  1.11469902e-01, -2.94259042e-02,
#         6.68883398e-02,  8.18925127e-02, -1.35407560e-02,  1.30719319e-01,
#        -4.98136692e-02, -2.86585856e-02,  3.41686495e-02,  6.37391489e-03,
#        -5.14767580e-02, -1.48535622e-02,  1.16304224e-02,  3.31624411e-02,
#         8.39071423e-02, -4.62575769e-03,  3.37552987e-02,  4.62888330e-02,
#         1.00725293e-01, -4.78773713e-02,  1.95520297e-02, -1.04587777e-02,
#         5.11016250e-02, -1.03912391e-01, -1.09255686e-03,  3.71696949e-02,
#        -4.00327370e-02,  4.22731824e-02, -4.34258394e-02,  7.20637366e-02,
#         5.05851693e-02, -3.13544529e-03,  8.12916532e-02,  1.09641016e-01,
#         2.12361161e-02, -1.26839429e-01, -7.47628063e-02, -3.72275896e-02,
#         2.28485512e-03,  1.08059086e-01, -7.51209185e-02, -2.13989783e-02,
#         3.87885484e-05,  4.41964529e-02,  9.43323895e-02, -7.32322335e-02,
#        -3.00771333e-02,  3.03019024e-02,  1.47596989e-02,  1.93408094e-02,
#         5.08729815e-02,  7.12663084e-02,  3.84745263e-02, -2.15589087e-02,
#         4.41283062e-02, -7.26787224e-02,  7.77175277e-02,  1.65539775e-02,
#         2.94277765e-04,  6.48821294e-02,  1.56225869e-02, -7.48147536e-03],
#       dtype=float32)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
google_embeddings_model = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

# %%
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# "AIzaSyADrqdhA3WeYgWx29dYL-c64XXhvytIO38"  #free

# %%
embedding = google_embeddings_model.embed_query("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/langchain_google_genai/embeddings.py:487, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     486 try:
# --> 487     result = self.client.models.embed_content(
#     488         model=self.model,
#     489         contents=text,
#     490         config=config,
#     491     )
#     492 except ClientError as e:
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/models.py:6189, in Models.embed_content(self, model, contents, config)
#    6188     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6189   return self._embed_content(model=model, contents=contents, config=config)
#    6191 if t.t_is_vertex_embed_content_model(model):
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/models.py:4996, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    4994 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4996 response = self._api_client.request(
#    4997     'post', path, request_dict, http_options
#    4998 )
#    5000 response_dict = {} if not response.body else json.loads(response.body)
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1579, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1576 http_request = self._build_request(
#    1577     http_method, path, request_dict, http_options
#    1578 )
# -> 1579 response = self._request(http_request, http_options, stream=False)
#    1580 response_body = (
#    1581     response.response_stream[0] if response.response_stream else ''
#    1582 )
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1372, in BaseApiClient._request(self, http_request, http_options, stream)
#    1370     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1372 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1349, in BaseApiClient._request_once(self, http_request, stream)
#    1348   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1349 errors.APIError.raise_for_response(response)
#    1350 return HttpResponse(
#    1351     response.headers, response if stream else [response.text]
#    1352 )
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 embedding = google_embeddings_model.embed_query("What is the capital of France?")
#
# File ~/Desktop/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/langchain_google_genai/embeddings.py:494, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     492 except ClientError as e:
#     493     msg = f"Error embedding content ({e.status}): {e}"
# --> 494     raise GoogleGenerativeAIError(msg) from e
#     495 except Exception as e:
#     496     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %%
len(embedding)

# %%
from langchain_openai import OpenAIEmbeddings

# %%
openai_embeddings_model=OpenAIEmbeddings(model="text-embedding-3-large")

# %%
embedding = openai_embeddings_model.embed_query("What is the capital of France?")

# %%
len(embedding)

# %%
openai_embeddings_small_model=OpenAIEmbeddings(model="text-embedding-3-small")

# %%
embedding = openai_embeddings_small_model.embed_query("What is the capital of France?")

# %%
len(embedding)

# %%
TEXT

IMAGE?

ViT(vision transformer) and CLIP(contrastive language-image pretraining) are two popular transformer-based models used for image processing tasks.

# %%
from transformers import CLIPModel, CLIPProcessor

# %%
from PIL import Image

# %%
image = Image.open("D:\complete_content_new\Full-Stack-GenAI-Bootcamp-1.0\Class-08-18-Apr-SOTA-Transformer-Embedding-Methods\image\sunny-savita.png")

# %%
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# %%
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

# %%
inputs =processor(images=image, return_tensors="pt")

# %%
import torch

# %%
# Get embedding
with torch.no_grad():
    image_embedding = model.get_image_features(**inputs)

# %%
image_embedding

# %%
len(image_embedding[0])

# %% [markdown]
# ## Semantic Search (Similarity Search)

# %% [markdown]
# 1. Dot Product
# 2. Cosine Sim
# 3. Eculidean Distance(L2)

# %%
def dot_product(a, b):
    return np.dot(a, b)

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
def euclidean_distance(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.linalg.norm(a - b)

# %%
print("=== Cosine Similarity (Higher is better) ===")
print("Range: -1 to 1")

print("\n=== Dot Product (Higher is better) ===")
print("Range: -∞ to +∞ (depends on vector magnitude)")

print("\n=== Euclidean Distance (Lower is better) ===")
print("Range: 0 to +∞")

# %%
query = "How to reduce heart disease risk?"

# %%
documents = [
    "Eating fiber reduces heart risk.",
    "Fruits and vegetables lower cardiovascular disease chances.",
    "Buying a new car improves driving comfort.",
    "Regular exercise improves heart health."
]

# %%
query_embedding = openai_embeddings_model.embed_query(query)

# %%
doc_embeddings = openai_embeddings_model.embed_documents(documents)

# %%
len(doc_embeddings)

# %%
len(doc_embeddings[0])

# %%
import numpy as np

# %%
results = []

# %%
for doc, doc_emb in zip(documents, doc_embeddings):
    results.append({
        "query": query,
        "document": doc,
        "cosine": cosine_similarity(query_embedding, doc_emb),
        "dot_product": dot_product(query_embedding, doc_emb),
        "euclidean": euclidean_distance(query_embedding, doc_emb)
    })

# %%
results

# %% [markdown]
# # Keyword Search

# %%
documents

# %%
query

# %%
from collections import Counter

# %%
query.lower().replace("?", "").split()

# %%
query_words = query.lower().replace("?", "").split()

# %%
documents[0]

# %%
doc_words = documents[0].lower().replace(".", "").split()

# %%
doc_words

# %%
doc_count = Counter(doc_words)

# %%
doc_count

# %%
for word in query_words:
    print(f"{word}: {doc_count[word]}")

# %%
score = sum(doc_count[word] for word in query_words)

# %% [markdown]
# # Score = number of matching words

# %%
score

# %%
def keyword_search(query, documents):
    query_words = query.lower().replace("?", "").split()
    results = []

    for doc in documents:
        doc_words = doc.lower().replace(".", "").split()
        doc_count = Counter(doc_words)

        score = sum(doc_count[word] for word in query_words) 
        results.append((doc, score))

    return sorted(results, key=lambda x: x[1], reverse=True)

# %%
keyword_results = keyword_search(query, documents)

# %%
keyword_results
